# %%
from evaluation_module import run_and_visualize
from paradigm_module.stroop_paradigm_module import StroopAgent, StroopEnvironment

if __name__ == "__main__":

    env = StroopEnvironment()
    agent = StroopAgent(state_size=8, action_size=4, base_dir='stroop_saved_models')

    # 运行模型并可视化结果
    agent, results = run_and_visualize(agent, env, episodes=600, n_trials=200)
    
    # 如果有人类数据，可以进行比较
    # compare_with_human_data(results, human_data)

    # 保存模型
    model_name = "stroop_1000.zip"
    agent.save(model_name=model_name)
# Out:
# 开始训练模型...
# f:\AI for science\CG2409 使用强化学习和有监督学习研究动作视觉任务\paradigm_module\stroop_paradigm_module.py:103: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\b\abs_8f7uhuge1i\croot\pytorch-select_1717607507421\work\torch\csrc\utils\tensor_new.cpp:277.)
#   states = torch.FloatTensor(states).to(self.device)
# 评估模型表现...
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Model performance statistics:
# ----------------------------------------
# 总体准确率: 0.930
#
# Statistics by condition:
#           correct            rt
#              mean    std   mean    std
# congruent
# False       0.927  0.261  0.600  0.144
# True        0.937  0.246  0.427  0.102
# 模型已保存到: stroop_saved_models\model_20241128_170709
